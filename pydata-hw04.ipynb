# %% [markdown]
# # Основы анализа данных в Python
#
# ## Домашнее задание №4
#
# ### Формат сдачи задания
#
# Для сдачи задания необходимо добавить в текущий ipynb-файл ячейки с кодом (и текстом, если требуются содержательные ответы на вопросы) после каждого задания, сохранить изменения и загрузить итоговый файл через запрос Dropbox по ссылке, предложенной преподавателем.
#
# Всего за задание можно получить 12 баллов.
#
# Дедлайн: 13 октября 23:59.

# %% [markdown]
# ### Часть 1: серьезная (6 баллов)
#
# Д. Асемоглу, С. Джонсон, и Д. А. Робинсон в статье “The Colonial Origins of Comparative Development: An Empirical Investigation” (2001) оценивали влияние институтов на экономическое благополучие. В соответствии с их теорией, текущее экономическое состояние бывших колоний зависит от типа институтов, которые европейцы создали в процессе колонизации. Тип институтов, в свою очередь, зависит от географического положения и природных условий в колонии.
#
# На первом этапе исследования авторы оценивают влияние риска экспроприации государством частного иностранного финансирования на ВВП на душу населения с учетом географических факторов, а именно удаленности от экватора и континента, на котором находится страна.
#
# В файле `research.csv` сохранены следующие переменные:
#
# * `shortnam` : сокращенное название страны;
#
# * `logpgp95` : логарифм ВВП на душу населения в 1995 году;
#
# * `avexpr` : индекс защищенности от экспроприации государством частного иностранного финансирования, усредненное значение за 1985-1995 годы, принимает значение от 0 до 10, где более высокие значения соответствуют меньшему риску;
#
# * `lat_abst` : мера расстояния до экватора, абсолютное значение широты, переведенное в шкалу от 0 до 1, где 0 соответствует экватору;
#
# * `africa`,`asia`, `america`, `other` : дамми-переменные, где 1 соответствует определенному континенту.

# %% [markdown]
# ### Задача 1 (4 балла)
#
# Постройте модель парной линейной регрессии, которая показала бы связь между риском экспроприации государством частного иностранного финансирования и ВВП на душу населения (в логарифмированном виде). Выведите выдачу с результатами на экран и проинтерпретируйте ее. Ваша интерпретация должна включать:
#
# * уравнение полученной модели;
# * пояснения к значениям коэффициентов $\hat{b}_0$ и $\hat{b}_1$;
# * комментарий о значимости коэффициента при независимой переменной;
# * комментарий о предсказательной силе модели.

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Используя библиотеку `seaborn`, постройте диаграмму рассеивания для показателей из предыдущей задачи с добавленной на нее регрессионной прямой.

# %% [markdown]
# ## Часть 2: несерьезная (6 баллов)
#
# В файле `nyc_squirrels.csv` сохранены данные по популяции белок, которые обитают в Центральном парке Нью-Йорка. Полное описание данных можно найти [здесь](https://github.com/rfordatascience/tidytuesday/tree/master/data/2019/2019-10-29), основные переменные в файле для этого задания следующие:
#
# * `lat` и `long`: широта и долгота точки, в которой производилось наблюдение за белками;
# * `date`: дата наблюдения;
# * `hectare_squirrel_number`: число замеченных белок в районе наблюдения;
# * `age`: возраст белок, закодирован значениями `Adult`, `Juvenile`, `?`;
# * `primary_fur_color`: основной цвет белок, закодирован значениями `Gray`, `Cinnamon`, `Black`.

# %% [markdown]
# ### Задача 1 (1 балл)
#
# Удалите строки датафрейма, которые содержат пропущенные значения в столбце с цветом белок (`primary_fur_color`). Строки с пропусками в других столбцах должны остаться в датафрейме.

# %% [markdown]
# ### Задача 2 (1 балл)
#
# Добавьте в датафрейм бинарный столбец `color`, где значения 1 соответствуют белкам рыжего цвета (`Cinnamon`), а значения 0 – всем остальным.

# %% [markdown]
# ### Задача 3 (2 балла)
#
# Постройте модель линейной регрессии, которая позволит понять, насколько шансы встретить рыжих белок выше шансов встретить белок другого цвета. Проинтерпретируйте полученные результаты. Ваша интерпретация должна включать пояснения к коэффициентам модели ($\hat{b}_0$, $\hat{b}_1$) и их статистической значимости. Прокомментируйте качество (предсказательную силу) полученной модели. Если оно не очень хорошее, приведите возможное объяснение, почему это так.

# %% [markdown]
# ### Задача 4 (1 балл)
#
# Используя библиотеку `seaborn`, постройте диаграмму рассеивания для широты и долготы точек, в которых производились наблюдения за белками. Приведите возможное объяснение, почему у этой диаграммы такой специфический вид. Просмотрите небольшую [статью](https://www.bloomberg.com/news/articles/2019-06-24/how-many-squirrels-are-in-nyc-s-central-park), написанную на основе этих данных и сделайте окончательный вывод об особенностях расположения точек на диаграмме.

# %% [markdown]
# ### Задача 5 (1 балл)
#
# Используя библиотеку `seaborn`, постройте диаграмму из предыдущей задачи, но с учетом того, что точки, соответствующие белкам разного цвета (`primary_fur_color`) тоже должны быть разного цвета. Можно ли сказать, что белки разного цвета сосредоточены в разных частях парка?
