# %% [markdown]
# # Основы анализа данных в Python
#
# ## Домашнее задание №6
#
# ### Формат сдачи задания
#
# Для сдачи задания необходимо добавить в текущий ipynb-файл ячейки с кодом (и текстом, если требуются содержательные ответы на вопросы) после каждого задания, сохранить изменения и загрузить итоговый файл через запрос Dropbox по ссылке, предложенной преподавателем.
#
# Всего за задание можно получить 15 баллов.
#
# Дедлайн: 23 октября 15:00.

# %% [markdown]
# Представьте, что перед вами стоит следующий исследовательский вопрос: каким образом политическая самоидентификация жителей Испании на шкале *левый-правый* зависит от того, ассоциирует ли житель себя с родным регионом или со всей страной?  Если более конкретно, правда ли, что жители, которые, прежде всего, ассоциируют себя со всей страной, а потом уже с регионом, более склонны придерживаться правых взглядов и одобрять соответствующую политику?
#
# В файле `spanish_data.csv` сохранены следующие переменные:
#
# * `ideolog` : позиция респондента на идеологическом спектре, закодированная 0 и 1, 1 – правый, 0 – левый;
#
# * `ident_reg` : 1 – респондент ассоциирует себя, прежде всего, с регионом, 0 – иначе;
#
# * `ident_cntr` : 1 – респондент ассоциирует себя, прежде всего, со страной, 0 – иначе;
#
# * `age` : возраст респондента;
#
# * `male` : 1 – мужской пол, 0 – женский;
#
# * `educ`: уровень образования (1 – начальное, 2 – среднее, 3 – среднее специальное, 4 – высшее);
#
# * `unempl`: 1 – безработный, 0 – иначе.
#
# Загрузите данные из файла `spanish_data.csv` и выполните следующие задания.

# %% [markdown]
# ### Задача 1 (3 балла)
#
# На основе имеющихся данных постройте модель логистической регрессии, которая позволит ответить на поставленный исследовательский вопрос. Помимо ключевой переменной интереса включите в модель **контрольные переменные** – возраст и пол респондента. Выведите выдачу с результатами на экран и проинтерпретируйте ее. Ваша интерпретация должна включать:
#
# * комментарий о значимости коэффициентов при независимых переменных (уровень значимости 5%);
# * комментарий о знаках коэффициентов при независимых переменных.

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Выведите медианные значения по всем независимым переменным, включенным в модель. Оцените предельные эффекты независимых переменных для медианного респондента (респондента, у которого все характеристики равны медиане). Проинтерпретируйте полученные результаты в терминах вероятностей.

# %% [markdown]
# ### Задача 3 (2 балла)
#
# Оцените средние предельные эффекты независимых переменных. Проинтерпретируйте полученные результаты в терминах вероятностей.

# %% [markdown]
# ### Задача 4 (1 балл)
#
# Вычислите, с какой вероятностью, согласно полученной модели, женщина 30 лет, которая ассоциирует себя, прежде всего, с регионом, придерживается правых взглядов.
#
# **Подсказка:** метод `.predict()` работает так же как и в линейной модели, в том числе с аргументом `exog`.

# %% [markdown]
# ### Задача 5 (3 балла)
#
# Используя функции из `sklearn.metrics`, вычислите *true positive rate*, *false positive rate* и показатель качества модели AUC (*area under curve*). Постройте ROC кривую для полученной модели и добавьте на график значение AUC. Проинтерпретируйте полученные результаты, а именно:
#
# * насколько велика способность модели верно предсказывать 1;
# * насколько велика способность модели верно предсказывать 0;
# * насколько велика, в целом, предсказательная сила модели.

# %% [markdown]
# ### Задача 6 (4 балла)
#
# Дополните модель из задачи 1, считая, что при изучении политической идентификации жителей Испании необходимо учитывать уровень образования и тот факт, является ли респондент безработным или нет.
#
# По аналогии с предыдущей задачей, вычислите *true positive rate*, *false positive rate* и показатель качества модели AUC для новой модели.
#
# Постройте на одном графике ROC кривую для первой модели и ROC кривую для второй модели, добавьте на график значения AUC для обеих моделей. Можно ли считать, что вторая модель существенно лучше первой, если оценивать ее исключительно с точки зрения качества предсказания вероятностей?
