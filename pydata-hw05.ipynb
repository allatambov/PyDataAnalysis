# %% [markdown]
# # Основы анализа данных в Python
#
# ## Домашнее задание №5
#
# ### Формат сдачи задания
#
# Для сдачи задания необходимо добавить в текущий ipynb-файл ячейки с кодом (и текстом, если требуются содержательные ответы на вопросы) после каждого задания, сохранить изменения и загрузить итоговый файл через запрос Dropbox по ссылке, предложенной преподавателем.
#
# Всего за задание можно получить 10 баллов.
#
# Дедлайн: 18 октября 23:59.

# %% [markdown]
# Д. Асемоглу, С. Джонсон, и Д. А. Робинсон в статье “The Colonial Origins of Comparative Development: An Empirical Investigation” (2001) оценивали влияние институтов на экономическое благополучие. В соответствии с их теорией, текущее экономическое состояние бывших колоний зависит от типа институтов, которые европейцы создали в процессе колонизации. Тип институтов, в свою очередь, зависит от географического положения и природных условий в колонии.
#
# На первом этапе исследования авторы оценивают влияние риска экспроприации государством частного иностранного финансирования на ВВП на душу населения с учетом географических факторов, а именно удаленности от экватора и континента, на котором находится страна.
#
# В файле `research.csv` сохранены следующие переменные:
#
# * `shortnam` : сокращенное название страны;
#
# * `logpgp95` : логарифм ВВП на душу населения в 1995 году;
#
# * `avexpr` : индекс защищенности от экспроприации государством частного иностранного финансирования, усредненное значение за 1985-1995 годы, принимает значение от 0 до 10, где более высокие значения соответствуют меньшему риску;
#
# * `lat_abst` : мера расстояния до экватора, абсолютное значение широты, переведенное в шкалу от 0 до 1, где 0 соответствует экватору;
#
# * `africa`, `asia`, `america`, `other` : дамми-переменные, где 1 соответствует определенному континенту.
#
# Загрузите данные из файла `research.csv` и выполните следующие задания.

# %% [markdown]
# ### Задача 0 (1 балл)
#
# Удалите в датафрейме строки с пропущенными значениями (неважно, в каком столбце содержится пропуск).

# %% [markdown]
# ### Задача 1 (4 балла)
#
# Постройте модель множественной линейной регрессии, которая показала бы, каким образом экономическое благополучие, измеренное как логарифм ВВП на душу населения, зависит от риска экспроприации государством частного иностранного финансирования, удаленности страны до экватора и континента, на котором расположена страна (Африка, Азия или другой, Америку включать не нужно). Выведите выдачу с результатами на экран и проинтерпретируйте ее. Ваша интерпретация должна включать:
#
# * уравнение полученной модели;
# * пояснения к значениям коэффициентов при независимых переменных;
# * комментарий о значимости коэффициентов при независимых переменных (уровень значимости 5%);
# * комментарий о предсказательной силе модели.
#
# **Важно.** В спецификации модели, предложенной в этом задании, а именно, в модели, где из дамми-переменных для континентов в качестве независимых переменных включаются все, кроме Америки, Америка является базовой (референтной) категорией, с которой сравниваются все остальные. Так, например, коэффициент при `africa` будет отвечать не просто за различия между странами Африки и остальными, а за различия между странами Африки и Америки. С остальными дамми-переменными история аналогичная.

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Используя `seaborn`, постройте график, который покажет, отличается ли характер взаимосвязи между удаленностью страны от экватора и ее экономическим благополучием у стран Африки (`africa = 1`) и всех остальных (`africa = 0`). Проинтерпретируйте полученные результаты.

# %% [markdown]
# ### Задача 3 (3 балла)
#
# Дополните модель из задачи 1, считая, что удаленность страны от экватора по-разному сказывается на экономическом благополучии стран, которые находятся в Африке и стран, которые находятся на всех остальных континетах. Выведите выдачу с результатами на экран и проинтерпретируйте ее. Ваша интерпретация должна включать:
#
# * уравнение полученной модели;
# * пояснения к значениям коэффициентов при независимых переменных;
# * комментарий о значимости коэффициентов при независимых переменных (уровень значимсоти 10%).
#
# Можно ли считать, что, действительно, удаленность страны от экватора по-разному сказывается на экономическом благополучии африканских и не-африканских стран? Обоснуйте свой ответ.
